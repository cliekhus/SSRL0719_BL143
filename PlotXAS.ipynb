# %%
import matplotlib.pyplot as plt
from averageScans import averageScans

# %%
XEnergy, I0, FF1, FF2, FF3, FF = averageScans('RuTpyBpyCN_10mM_089', 3, True)
# Out:
# Data/RuTpyBpyCN_10mM_089_001.dat
# Data/RuTpyBpyCN_10mM_089_002.dat
# Data/RuTpyBpyCN_10mM_089_003.dat

# %%
plt.plot(XEnergy, [(w+x+y)/z for w,x,y,z in zip(FF1,FF2,FF3,I0)])
plt.xlabel('xray energy (eV)')
plt.title('XAS (TFY)')
# Out:
# Text(0.5, 1.0, 'XAS (TFY)')

# %%
XEnergy, I0, FF1, FF2, FF3, FF = averageScans('RuTpyBpyCN_10mM_090', 2,False)
# Out:
# Data/RuTpyBpyCN_10mM_090_001.dat
# Data/RuTpyBpyCN_10mM_090_002.dat

# %%
plt.plot(XEnergy, [(w+x+y)/z for w,x,y,z in zip(FF1,FF2,FF3,I0)])
plt.xlabel('xray energy (eV)')
plt.title('XAS (TFY)')
# Out:
# Text(0.5, 1.0, 'XAS (TFY)')
